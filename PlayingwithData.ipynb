# %%
import numpy as np
import mne

# %%
raw_data = mne.io.read_raw_eeglab('data/ds004504//derivatives/sub002/eeg/sub-002_task-eyesclosed_eeg.set')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raw_data = mne.io.read_raw_eeglab('data/ds004504//derivatives/sub002/eeg/sub-002_task-eyesclosed_eeg.set')
#
# File /Applications/miniconda3/lib/python3.10/site-packages/mne/io/eeglab/eeglab.py:311, in read_raw_eeglab(input_fname, eog, preload, uint16_codec, montage_units, verbose)
#     270 @fill_doc
#     271 def read_raw_eeglab(
#     272     input_fname,
#    (...)
#     277     verbose=None,
#     278 ):
#     279     r"""Read an EEGLAB .set file.
#     280
#     281     Parameters
#    (...)
#     309     .. versionadded:: 0.11.0
#     310     """
# --> 311     return RawEEGLAB(
#     312         input_fname=input_fname,
#     313         preload=preload,
#     314         eog=eog,
#     315         uint16_codec=uint16_codec,
#     316         montage_units=montage_units,
# ...

# %%
print(raw_data.info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, T5, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  dig: 22 items (3 Cardinal, 19 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >

# %%
print(type(raw_data))
# Out:
# <class 'mne.io.eeglab.eeglab.RawEEGLAB'>

# %%
raw_data.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
epochs = mne.Epochs(raw_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 epochs = mne.Epochs(raw_data)
#
# TypeError: __init__() missing 1 required positional argument: 'events'
