# %%
import numpy as np
import mne

# %%
raw_data = mne.io.read_raw_eeglab('data/ds004504/derivatives/sub-002/eeg/sub-002_task-eyesclosed_eeg.set')
# Out:
# /var/folders/42/2zjv5vys3693nls8j787kc2c0000gn/T/ipykernel_1063/2097649088.py:1: RuntimeWarning: Data will be preloaded. preload=False or a string preload is not supported when the data is stored in the .set file
#   raw_data = mne.io.read_raw_eeglab('data/ds004504/derivatives/sub-002/eeg/sub-002_task-eyesclosed_eeg.set')

# %%
print(raw_data.info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, T5, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  dig: 22 items (3 Cardinal, 19 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 19
#  projs: []
#  sfreq: 500.0 Hz
# >

# %%
print(type(raw_data))
# Out:
# <class 'mne.io.eeglab.eeglab.RawEEGLAB'>

# %%
raw_data.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
epochs = mne.Epochs(raw_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 epochs = mne.Epochs(raw_data)
#
# TypeError: __init__() missing 1 required positional argument: 'events'
